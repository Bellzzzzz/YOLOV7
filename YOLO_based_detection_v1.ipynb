# %% [markdown]
# <a href="https://colab.research.google.com/github/KosarBehnia/YOLO_Object_detection/blob/main/YOLO_based_detection_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
['pedestrian', 'people', 'bicycle', 'car', 'van', 'truck', 'tricycle', 'awning-tricycle', 'bus', 'motor']
# Out:
# ['pedestrian',
#  'people',
#  'bicycle',
#  'car',
#  'van',
#  'truck',
#  'tricycle',
#  'awning-tricycle',
#  'bus',
#  'motor']

# %% [markdown]
# # New Section

# %%
# !pip install ultralyticsplus==0.0.28 ultralytics==8.0.43
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.6/299.6 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 36.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.2/213.2 kB 25.3 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=9648585602eb7c6577bd843cb93ae7d88cb0ffd877a60377fbf4ff3aaac9eb9c
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# ...

# %%
from ultralyticsplus import YOLO, render_result

# load model
model = YOLO('mshamrai/yolov8n-visdrone')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# set image
image = 'temp.PNG'

# perform inference
results = model.predict(image)

# observe results
print(results[0].boxes)
render = render_result(model=model, image=image, result=results[0])
render.show()
# Out:
# ...
# Ultralytics YOLOv8.0.43 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU
# Model summary (fused): 168 layers, 3007598 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/temp.PNG: 416x640 17 pedestrians, 4 peoples, 196.8ms
# Speed: 2.3ms preprocess, 196.8ms inference, 22.4ms postprocess per image at shape (1, 3, 640, 640)
# tensor([[4.23000e+02, 1.00000e+00, 4.44000e+02, 4.70000e+01, 8.09265e-01, 0.00000e+00],
#         [3.86000e+02, 2.04000e+02, 4.17000e+02, 2.67000e+02, 6.99791e-01, 0.00000e+00],
#         [6.67000e+02, 3.20000e+01, 6.91000e+02, 8.80000e+01, 6.56265e-01, 0.00000e+00],
#         [2.58000e+02, 1.19000e+02, 2.82000e+02, 1.71000e+02, 6.49217e-01, 0.00000e+00],
#         [7.37000e+02, 3.46000e+02, 7.65000e+02, 4.09000e+02, 5.92700e-01, 0.00000e+00],
#         [2.01000e+02, 1.00000e+00, 2.21000e+02, 3.80000e+01, 5.75833e-01, 0.00000e+00],
#         [5.32000e+02, 8.50000e+01, 5.56000e+02, 1.42000e+02, 5.42607e-01, 0.00000e+00],
# ...
